# %% [markdown]
# # SOFA 2026 Logistics Dashboard: Data Quality and Structure
#
# This notebook inspects the public synthetic dataset only.

# %%
from pathlib import Path
import pandas as pd

path = Path('..') / 'data' / 'synthetic' / 'logistics_demo.csv'
df = pd.read_csv(path)
df.head()

# %%
df.describe(include='all').transpose()[['count', 'unique', 'top', 'freq']]

# %%
df.groupby(['Pavilion', 'Operational Status']).size().unstack(fill_value=0)
